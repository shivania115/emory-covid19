# %%
# %%time
# %run preprocessing_nationalraw-mongodb.ipynb
# Out:
# Requirement already satisfied: dnspython in /opt/anaconda3/lib/python3.7/site-packages (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# kevin
# preprocessing_nationalraw-mongodb.ipynb:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "cell_type": "code",
# preprocessing_nationalraw-mongodb.ipynb:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "cell_type": "code",
# preprocessing_nationalraw-mongodb.ipynb:247: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 2min 2s, sys: 2.07 s, total: 2min 4s
# Wall time: 2min 53s

# %%
# %%time
# %run preprocessing_timeseries-mongodb.ipynb
# Out:
# Requirement already satisfied: dnspython in /opt/anaconda3/lib/python3.7/site-packages (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# kevin
# CPU times: user 2min 11s, sys: 3.94 s, total: 2min 15s
# Wall time: 5min 47s

# %%
# %%time
# %run preprocessing_timeseriesALL-mongodb.ipynb
# Out:
# kevin
# CPU times: user 1min 31s, sys: 891 ms, total: 1min 32s
# Wall time: 1min 33s

# %%
# %%time
# %run preprocessing_top10trendlines-mongodb.ipynb
# Out:
# kevin
# CPU times: user 510 ms, sys: 20 ms, total: 530 ms
# Wall time: 1.76 s

# %%
# %%time
# %run preprocessing_top10county-mongodb.ipynb
# Out:
# kevin
# CPU times: user 90.3 ms, sys: 17.3 ms, total: 108 ms
# Wall time: 707 ms

# %%
# %%time
# %run preprocessing_nationalBarChart-mongodb.ipynb
# Out:
# kevin
# CPU times: user 106 ms, sys: 19 ms, total: 125 ms
# Wall time: 612 ms

# %%
# %%time
# %run preprocessing_VaccineStatic-mongo.ipynb
# Out:
# kevin
# CPU times: user 92.7 ms, sys: 18.8 ms, total: 112 ms
# Wall time: 974 ms

# %%
# %%time
# %run preprocessing_Vaccine_timeseries-mongo.ipynb
# Out:
# defaultdict(<class 'dict'>, {'01': [{'t': 1611550800, 'distT': 1611378000, 'percentVaccinatedDose2_avg7': 0.46}, {'t': 1612242000, 'distT': 1612242000, 'percentVaccinatedDose2_avg7': 0.99}, {'t': 1612933200, 'distT': 1612933200, 'percentVaccinatedDose2_avg7': 1.72}, {'t': 1613624400, 'distT': 1613538000, 'percentVaccinatedDose2_avg7': 2.84}, {'t': 1614661200, 'distT': 1614661200, 'percentVaccinatedDose2_avg7': 5.47}, {'t': 1615867200, 'distT': 1615867200, 'percentVaccinatedDose2_avg7': 8.85}, {'t': 1616644800, 'distT': 1616644800, 'percentVaccinatedDose2_avg7': 10.91}, {'t': 1617595200, 'distT': 1617595200, 'percentVaccinatedDose2_avg7': 12.64}, {'t': 1618459200, 'distT': 1618459200, 'percentVaccinatedDose2_avg7': 15.26}, {'t': 1619409600, 'distT': 1619409600, 'percentVaccinatedDose2_avg7': 18.67}, {'t': 1620187200, 'distT': 1620187200, 'percentVaccinatedDose2_avg7': 21.74}, {'t': 1620878400, 'distT': 1620878400, 'percentVaccinatedDose2_avg7': 24.07}, {'t': 1622001600, 'distT': 1622001600, 'percentVaccinatedDose2_avg7': 26.34}, {'t': 1622779200, 'distT': 1622779200, 'percentVaccinatedDose2_avg7': 27.17}, {'t': 1623729600, 'distT': 1623729600, 'percentVaccinatedDose2_avg7': 27.87}, {'t': 1624507200, 'distT': 1624507200, 'percentVaccinatedDose2_avg7': 29.43}, {'t': 1625371200, 'distT': 1625371200, 'percentVaccinatedDose2_avg7': 30.2}, {'t': 1626235200, 'distT': 1626235200, 'percentVaccinatedDose2_avg7': 30.81}, {'t': 1627876800, 'distT': 1627876800, 'percentVaccinatedDose2_avg7': 31.39}, {'t': 1628654400, 'distT': 1628654400, 'percentVaccinatedDose2_avg7': 32.2}, {'t': 1629432000, 'distT': 1629432000, 'percentVaccinatedDose2_avg7': 32.96}], '02': [{'t': 1611550800, 'distT': 1611378000, 'percentVaccinatedDose2_avg7': 1.78}, {'t': 1612242000, 'distT': 1612242000, 'percentVaccinatedDose2_avg7': 3.08}, {'t': 1612933200, 'distT': 1612933200, 'percentVaccinatedDose2_avg7': 5.02}, {'t': 1613624400, 'distT': 1613278800, 'percentVaccinatedDose2_avg7': 7.62}, {'t': 1614661200, 'distT': 1614661200, 'percentVaccinatedDose2_avg7': 12.36}, {'t': 1615867200, 'distT': 1615867200, 'percentVaccinatedDose2_avg7': 16.46}, {'t': 1616644800, 'distT': 1616644800, 'percentVaccinatedDose2_avg7': 19.36}, {'t': 1617595200, 'distT': 1617595200, 'percentVaccinatedDose2_avg7': 21.7}, {'t': 1618459200, 'distT': 1618459200, 'percentVaccinatedDose2_avg7': 26.41}, {'t': 1619409600, 'distT': 1619409600, 'percentVaccinatedDose2_avg7': 31.0}, {'t': 1620187200, 'distT': 1620187200, 'percentVaccinatedDose2_avg7': 33.41}, {'t': 1620878400, 'distT': 1620878400, 'percentVaccinatedDose2_avg7': 34.84}, {'t': 1622001600, 'distT': 1621915200, 'percentVaccinatedDose2_avg7': 35.97}, {'t': 1622779200, 'distT': 1622779200, 'percentVaccinatedDose2_avg7': 36.7}, {'t': 1623729600, 'distT': 1623729600, 'percentVaccinatedDose2_avg7': 37.81}, {'t': 1624507200, 'distT': 1624507200, 'percentVaccinatedDose2_avg7': 38.66}, {'t': 1625371200, 'distT': 1625198400, 'percentVaccinatedDose2_avg7': 39.77}, {'t': 1626235200, 'distT': 1626235200, 'percentVaccinatedDose2_avg7': 41.0}, {'t': 1627876800, 'distT': 1627876800, 'percentVaccinatedDose2_avg7': 41.56}, {'t': 1628654400, 'distT': 1628568000, 'percentVaccinatedDose2_avg7': 42.13}, {'t': 1629432000, 'distT': 1629432000, 'percentVaccinatedDose2_avg7': 42.53}], '04': [{'t': 1611550800, 'distT': 1611378000, 'percentVaccinatedDose2_avg7': 0.61}, {'t': 1612242000, 'distT': 1612242000, 'percentVaccinatedDose2_avg7': 1.19}, {'t': 1612933200, 'distT': 1612933200, 'percentVaccinatedDose2_avg7': 2.01}, {'t': 1613624400, 'distT': 1613451600, 'percentVaccinatedDose2_avg7': 3.36}, {'t': 1614661200, 'distT': 1614661200, 'percentVaccinatedDose2_avg7': 6.44}, {'t': 1615867200, 'distT': 1615867200, 'percentVaccinatedDose2_avg7': 10.95}, {'t': 1616644800, 'distT': 1616644800, 'percentVaccinatedDose2_avg7': 13.81}, {'t': 1617595200, 'distT': 1617595200, 'percentVaccinatedDose2_avg7': 16.51}, {'t': 1618459200, 'distT': 1618459200, 'percentVaccinatedDose2_avg7': ...
# CPU times: user 1.78 s, sys: 48.5 ms, total: 1.83 s
# Wall time: 3.39 s

# %%
# %%time
# %run national_demog-mongodb.ipynb
# %run preprocessing_national_demog_wVaccine-mongodb.ipynb
# Out:
# kevin
# CPU times: user 129 ms, sys: 17 ms, total: 146 ms
# Wall time: 433 ms

# %%
# %%time
# %run preprocessing_vaccineTrends-mongodb.ipynb
# Out:
# kevin
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# ...
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# CPU times: user 565 ms, sys: 117 ms, total: 682 ms
# Wall time: 1.13 s

# %%
# %%time
# %run preprocessing_vaccinationByRace-mongodb.ipynb
# Out:
# kevin
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Desktop/program/Shivani/emory-covid19/public/data/rawdata/preprocessing_vaccinationByRace-mongodb.ipynb in <module>
#     104 if __name__=="__main__":
#     105
# --> 106     vaccinationByRaceState()
#
# ~/Desktop/program/Shivani/emory-covid19/public/data/rawdata/preprocessing_vaccinationByRace-mongodb.ipynb in vaccinationByRaceState(fn)
#      69     date = ""
#      70     k = ""
# ---> 71     with open(fn, "r") as fp:
#      72         reader = csv.reader(fp)
#      73         header = next(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kffstaterace_static.csv'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <timed eval> in <module>
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2812                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2813                     if raise_exceptions:
# -> 2814                         result.raise_error()
#    2815                     elif not result.success:
#    2816                         break
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-11-6b3765261bec> in <module>
#     104 if __name__=="__main__":
#     105
# --> 106     vaccinationByRaceState()
#
# <ipython-input-11-6b3765261bec> in vaccinationByRaceState(fn)
#      69     date = ""
#      70     k = ""
# ---> 71     with open(fn, "r") as fp:
#      72         reader = csv.reader(fp)
#      73         header = next(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kffstaterace_static.csv'

# %%
# %%time
# %run preprocessing_staticracedata2-mongodb.ipynb
# Out:
# kevin
# CPU times: user 101 ms, sys: 17.6 ms, total: 118 ms
# Wall time: 2.14 s
