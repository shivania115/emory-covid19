# %%
# %%time
# %run preprocessing_nationalraw-mongodb.ipynb
# Out:
# Requirement already satisfied: dnspython in /Applications/Anaconda/anaconda3/lib/python3.7/site-packages (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# star
# CPU times: user 3.58 s, sys: 595 ms, total: 4.18 s
# Wall time: 1min 39s

# %%
# %%time
# %run preprocess_timeseries-mongodb.ipynb
# Out:
# Requirement already satisfied: dnspython in /Applications/Anaconda/anaconda3/lib/python3.7/site-packages (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# star
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocess_timeseries-mongodb.ipynb in <module>
#     247 if __name__=="__main__":
#     248
# --> 249     linechart()
#
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocess_timeseries-mongodb.ipynb in linechart(fn)
#     167                 continue
#     168
# --> 169             item = get_lineitem(d)
#     170             k = ""
#     171             if d["nation"] != "":
#
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocess_timeseries-mongodb.ipynb in get_lineitem(d)
#      46         caserate7dayfig = float(d["caserate7dayfig"])
#      47         covidmortality7dayfig = float(d["covidmortality7dayfig"])
# ---> 48         tests = int(d["tests"])
#      49         totalHospitalized = int(d["hospTot"])
#      50         testingRate = float(d["testingRate"])
#
# KeyError: 'tests'
# CPU times: user 195 ms, sys: 159 ms, total: 354 ms
# Wall time: 3.47 s

# %%
# %%time
# %run preprocess_timeseriesALL-mongodb.ipynb
# Out:
# star
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocess_timeseriesALL-mongodb.ipynb in <module>
#     247 if __name__=="__main__":
#     248
# --> 249     linechart2()
#
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocess_timeseriesALL-mongodb.ipynb in linechart2(fn)
#     166                 continue
#     167
# --> 168             item = get_lineitem(d)
#     169             k = ""
#     170             if d["nation"] != "":
#
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocess_timeseriesALL-mongodb.ipynb in get_lineitem(d)
#      45         caserate7dayfig = float(d["caserate7dayfig"])
#      46         covidmortality7dayfig = float(d["covidmortality7dayfig"])
# ---> 47         tests = int(d["tests"])
#      48         totalHospitalized = int(d["hospTot"])
#      49         testingRate = float(d["testingRate"])
#
# KeyError: 'tests'
# CPU times: user 73.2 ms, sys: 8.66 ms, total: 81.9 ms
# Wall time: 333 ms

# %%
# %%time
# %run staticracedata2-mongodb.ipynb
# Out:
# star
# CPU times: user 116 ms, sys: 11.5 ms, total: 127 ms
# Wall time: 1.42 s

# %%
# %%time
# %run top10trendlines-mongodb.ipynb
# Out:
# star
# CPU times: user 325 ms, sys: 26.8 ms, total: 352 ms
# Wall time: 911 ms

# %%
# %%time
# %run top10county-mongodb.ipynb
# Out:
# star
# CPU times: user 47 ms, sys: 7.64 ms, total: 54.6 ms
# Wall time: 357 ms

# %%
# %%time
# %run nationalMortalityBar-mongodb.ipynb
# Out:
# star
# CPU times: user 56.8 ms, sys: 7.8 ms, total: 64.6 ms
# Wall time: 410 ms

# %%
# %%time
# %run nationalCasesBar-mongodb.ipynb
# Out:
# star
# CPU times: user 52 ms, sys: 7.57 ms, total: 59.6 ms
# Wall time: 385 ms
