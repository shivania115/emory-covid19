# %%
# %%time
# %run preprocessing_nationalraw-mongodb.ipynb
# Out:
# Requirement already satisfied: dnspython in /Applications/Anaconda/anaconda3/lib/python3.7/site-packages (2.0.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/Applications/Anaconda/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# star
# preprocessing_nationalraw-mongodb.ipynb:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# preprocessing_nationalraw-mongodb.ipynb:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocessing_nationalraw-mongodb.ipynb in <module>
#      25 fig.update_traces(marker_line_width=0.3)
#      26 # fig.show()
# ---> 27 fig.write_image("../../NationalReportImages/ccvi.png")
#      28
#      29 img = Image.open(r"../../NationalReportImages/ccvi.png")
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3804         import plotly.io as pio
#    3805
# -> 3806         return pio.write_image(self, *args, **kwargs)
#    3807
#    3808     # Static helpers
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/plotly/io/_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     250         height=height,
#     251         validate=validate,
# --> 252         engine=engine,
#     253     )
#     254
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/plotly/io/_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     107             height=height,
#     108             scale=scale,
# --> 109             validate=validate,
#     110         )
#     111     elif engine != "kaleido":
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/plotly/io/_orca.py in to_image(fig, format, width, height, scale, validate)
#    1533     # Make sure orca sever is running
#    1534     # -------------------------------
# -> 1535     ensure_server()
#    1536
#    1537     # Handle defaults
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/plotly/io/_orca.py in ensure_server()
#    1388         # Validate orca executable only if server_url is not provided
#    1389         if status.state == "unvalidated":
# -> 1390             validate_executable()
#    1391         # Acquire lock to make sure that we keep the properties of orca_state
#    1392         # consistent across threads
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/plotly/io/_orca.py in validate_executable()
#    1085                 executable=config.executable,
#    1086                 formatted_path=formatted_path,
# -> 1087                 instructions=install_location_instructions,
#    1088             )
#    1089         )
#
# ValueError:
# The orca executable is required to export figures as static images,
# but it could not be found on the system path.
#
# Searched for executable 'orca' on the following path:
#     /anaconda3/bin
#     /usr/local/bin
#     /usr/bin
#     /bin
#     /usr/sbin
#     /sbin
#     /opt/X11/bin
#     /Library/Apple/usr/bin
#
# If you haven't installed orca yet, you can do so using conda as follows:
#
#     $ conda install -c plotly plotly-orca
#
# Alternatively, see other installation methods in the orca project README at
# https://github.com/plotly/orca
#
# After installation is complete, no further configuration should be needed.
#
# If you have installed orca, then for some reason plotly.py was unable to
# locate it. In this case, set the `plotly.io.orca.config.executable`
# property to the full path of your orca executable. For example:
#
#     >>> plotly.io.orca.config.executable = '/path/to/orca'
#
# After updating this executable property, try the export operation again.
# If it is successful then you may want to save this configuration so that it
# will be applied automatically in future sessions. You can do this as follows:
#
#     >>> plotly.io.orca.config.save()
#
# If you're still having trouble, feel free to ask for help on the forums at
# https://community.plot.ly/c/api/python
# CPU times: user 59.7 s, sys: 1.16 s, total: 1min
# Wall time: 1min 6s

# %%
# %%time
# %run preprocessing_timeseries-mongodb.ipynb
# Out:
# Requirement already satisfied: dnspython in /Applications/Anaconda/anaconda3/lib/python3.7/site-packages (2.0.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/Applications/Anaconda/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# star
# CPU times: user 1min 50s, sys: 3.65 s, total: 1min 53s
# Wall time: 6min 58s

# %%
# %%time
# %run preprocessing_timeseriesALL-mongodb.ipynb
# Out:
# star
# CPU times: user 1min 29s, sys: 845 ms, total: 1min 30s
# Wall time: 1min 33s

# %%
# %%time
# %run preprocessing_top10trendlines-mongodb.ipynb
# Out:
# star
# CPU times: user 460 ms, sys: 17.7 ms, total: 478 ms
# Wall time: 1.14 s

# %%
# %%time
# %run preprocessing_top10county-mongodb.ipynb
# Out:
# star
# CPU times: user 54.6 ms, sys: 10.3 ms, total: 64.8 ms
# Wall time: 381 ms

# %%
# %%time
# %run preprocessing_nationalBarChart-mongodb.ipynb
# Out:
# star
# CPU times: user 64.5 ms, sys: 11.1 ms, total: 75.6 ms
# Wall time: 451 ms

# %%
# %%time
# %run preprocessing_VaccineStatic-mongo.ipynb
# Out:
# star
# CPU times: user 55.4 ms, sys: 10.7 ms, total: 66.1 ms
# Wall time: 409 ms

# %%
# %%time
# %run preprocessing_Vaccine_timeseries-mongo.ipynb
# Out:
# CPU times: user 520 ms, sys: 23.9 ms, total: 544 ms
# Wall time: 1.52 s

# %%
# %%time
# %run national_demog-mongodb.ipynb
# %run preprocessing_national_demog_wVaccine-mongodb.ipynb
# Out:
# star
# CPU times: user 190 ms, sys: 15.9 ms, total: 206 ms
# Wall time: 589 ms

# %%
# %%time
# %run preprocessing_vaccinationByRace-mongodb.ipynb
# Out:
# star
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocessing_vaccinationByRace-mongodb.ipynb in <module>
#     104 if __name__=="__main__":
#     105
# --> 106     vaccinationByRaceState()
#
# ~/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/Dashboard/emory-covid19/public/data/rawdata/preprocessing_vaccinationByRace-mongodb.ipynb in vaccinationByRaceState(fn)
#      69     date = ""
#      70     k = ""
# ---> 71     with open(fn, "r") as fp:
#      72         reader = csv.reader(fp)
#      73         header = next(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kffstaterace_static.csv'
# CPU times: user 342 ms, sys: 311 ms, total: 653 ms
# Wall time: 1.98 s

# %%
# %%time
# %run preprocessing_staticracedata2-mongodb.ipynb
