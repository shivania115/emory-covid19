# %%
# %%time
# %run preprocessing_nationalraw-mongodb.ipynb
# Out:
# Requirement already satisfied: dnspython in /opt/anaconda3/lib/python3.7/site-packages (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# kevin
# preprocessing_nationalraw-mongodb.ipynb:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "cell_type": "code",
# preprocessing_nationalraw-mongodb.ipynb:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "cell_type": "code",
# preprocessing_nationalraw-mongodb.ipynb:247: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 1min 59s, sys: 2.25 s, total: 2min 1s
# Wall time: 2min 51s

# %%
# %%time
# %run preprocessing_timeseries-mongodb.ipynb
# Out:
# Requirement already satisfied: dnspython in /opt/anaconda3/lib/python3.7/site-packages (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# kevin
# CPU times: user 2min 16s, sys: 7.94 s, total: 2min 24s
# Wall time: 15min 48s

# %%
# %%time
# %run preprocessing_timeseriesALL-mongodb.ipynb
# Out:
# kevin
# CPU times: user 1min 31s, sys: 925 ms, total: 1min 32s
# Wall time: 1min 40s

# %%
# %%time
# %run preprocessing_top10trendlines-mongodb.ipynb
# Out:
# kevin
# CPU times: user 530 ms, sys: 31.7 ms, total: 562 ms
# Wall time: 3.36 s

# %%
# %%time
# %run preprocessing_top10county-mongodb.ipynb
# Out:
# kevin
# CPU times: user 111 ms, sys: 21.9 ms, total: 133 ms
# Wall time: 1.59 s

# %%
# %%time
# %run preprocessing_nationalBarChart-mongodb.ipynb
# Out:
# kevin
# CPU times: user 109 ms, sys: 18.9 ms, total: 127 ms
# Wall time: 1.55 s

# %%
# %%time
# %run preprocessing_VaccineStatic-mongo.ipynb
# Out:
# kevin
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/program/Shivani/emory-covid19/public/data/rawdata/preprocessing_VaccineStatic-mongo.ipynb in <module>
#      54 if __name__=="__main__":
#      55
# ---> 56     vaxstatic()
#
# ~/Desktop/program/Shivani/emory-covid19/public/data/rawdata/preprocessing_VaccineStatic-mongo.ipynb in vaxstatic(fn)
#      27                     if(k == "distDate"):
#      28                         d_new[k] = d[k]
# ---> 29                     d_new[k] = float(d[k])
#      30                 except ValueError:
#      31                     pass
#
# KeyError: 'Dist_Per_100K_new'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <timed eval> in <module>
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2812                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2813                     if raise_exceptions:
# -> 2814                         result.raise_error()
#    2815                     elif not result.success:
#    2816                         break
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-7-9db07de459bc> in <module>
#      54 if __name__=="__main__":
#      55
# ---> 56     vaxstatic()
#
# <ipython-input-7-9db07de459bc> in vaxstatic(fn)
#      27                     if(k == "distDate"):
#      28                         d_new[k] = d[k]
# ---> 29                     d_new[k] = float(d[k])
#      30                 except ValueError:
#      31                     pass
#
# KeyError: 'Dist_Per_100K_new'

# %%
# %%time
# %run preprocessing_Vaccine_timeseries-mongo.ipynb
# Out:
# defaultdict(<class 'dict'>, {'01': [{'t': 1611550800, 'distT': 1611378000, 'percentVaccinatedDose2_avg7': 0.46}, {'t': 1612242000, 'distT': 1612242000, 'percentVaccinatedDose2_avg7': 0.99}, {'t': 1612933200, 'distT': 1612933200, 'percentVaccinatedDose2_avg7': 1.72}, {'t': 1613624400, 'distT': 1613538000, 'percentVaccinatedDose2_avg7': 2.84}, {'t': 1614661200, 'distT': 1614661200, 'percentVaccinatedDose2_avg7': 5.47}, {'t': 1615867200, 'distT': 1615867200, 'percentVaccinatedDose2_avg7': 8.85}, {'t': 1616644800, 'distT': 1616644800, 'percentVaccinatedDose2_avg7': 10.91}, {'t': 1617595200, 'distT': 1617595200, 'percentVaccinatedDose2_avg7': 12.64}, {'t': 1618459200, 'distT': 1618459200, 'percentVaccinatedDose2_avg7': 15.26}, {'t': 1619409600, 'distT': 1619409600, 'percentVaccinatedDose2_avg7': 18.67}, {'t': 1620187200, 'distT': 1620187200, 'percentVaccinatedDose2_avg7': 21.74}, {'t': 1620878400, 'distT': 1620878400, 'percentVaccinatedDose2_avg7': 24.07}, {'t': 1622001600, 'distT': 1622001600, 'percentVaccinatedDose2_avg7': 26.47}, {'t': 1622779200, 'distT': 1622779200, 'percentVaccinatedDose2_avg7': 27.17}, {'t': 1623729600, 'distT': 1623729600, 'percentVaccinatedDose2_avg7': 27.87}, {'t': 1624507200, 'distT': 1624507200, 'percentVaccinatedDose2_avg7': 29.43}, {'t': 1625371200, 'distT': 1625371200, 'percentVaccinatedDose2_avg7': 30.2}, {'t': 1626235200, 'distT': 1626235200, 'percentVaccinatedDose2_avg7': 30.81}, {'t': 1627876800, 'distT': 1627876800, 'percentVaccinatedDose2_avg7': 31.44}, {'t': 1628654400, 'distT': 1628654400, 'percentVaccinatedDose2_avg7': 32.2}], '02': [{'t': 1611205200, 'distT': 1611205200, 'percentVaccinatedDose2_avg7': 14.95}, {'t': 1611982800, 'distT': 1611982800, 'percentVaccinatedDose2_avg7': 2.54}, {'t': 1612674000, 'distT': 1612587600, 'percentVaccinatedDose2_avg7': 4.05}, {'t': 1613278800, 'distT': 1613192400, 'percentVaccinatedDose2_avg7': 6.4}, {'t': 1614229200, 'distT': 1614229200, 'percentVaccinatedDose2_avg7': 10.37}, {'t': 1615352400, 'distT': 1615352400, 'percentVaccinatedDose2_avg7': 14.51}, {'t': 1616385600, 'distT': 1616385600, 'percentVaccinatedDose2_avg7': 18.4}, {'t': 1617163200, 'distT': 1617163200, 'percentVaccinatedDose2_avg7': 20.63}, {'t': 1618200000, 'distT': 1618200000, 'percentVaccinatedDose2_avg7': 23.63}, {'t': 1618977600, 'distT': 1618977600, 'percentVaccinatedDose2_avg7': 29.77}, {'t': 1619755200, 'distT': 1619755200, 'percentVaccinatedDose2_avg7': 32.39}, {'t': 1620619200, 'distT': 1620446400, 'percentVaccinatedDose2_avg7': 34.46}, {'t': 1621569600, 'distT': 1621569600, 'percentVaccinatedDose2_avg7': 35.47}, {'t': 1622520000, 'distT': 1622347200, 'percentVaccinatedDose2_avg7': 36.44}, {'t': 1623384000, 'distT': 1623384000, 'percentVaccinatedDose2_avg7': 37.37}, {'t': 1624248000, 'distT': 1623988800, 'percentVaccinatedDose2_avg7': 38.34}, {'t': 1625025600, 'distT': 1625025600, 'percentVaccinatedDose2_avg7': 39.21}, {'t': 1625803200, 'distT': 1625803200, 'percentVaccinatedDose2_avg7': 40.57}, {'t': 1626753600, 'distT': 1626753600, 'percentVaccinatedDose2_avg7': 41.33}, {'t': 1628222400, 'distT': 1628222400, 'percentVaccinatedDose2_avg7': 41.9}], '04': [{'t': 1610686800, 'distT': 1610686800, 'percentVaccinatedDose2_avg7': 36.4}, {'t': 1611723600, 'distT': 1611723600, 'percentVaccinatedDose2_avg7': 0.7}, {'t': 1612328400, 'distT': 1612328400, 'percentVaccinatedDose2_avg7': 1.25}, {'t': 1613019600, 'distT': 1613019600, 'percentVaccinatedDose2_avg7': 2.19}, {'t': 1613970000, 'distT': 1613970000, 'percentVaccinatedDose2_avg7': 3.76}, {'t': 1614834000, 'distT': 1614834000, 'percentVaccinatedDose2_avg7': 6.94}, {'t': 1615953600, 'distT': 1615953600, 'percentVaccinatedDose2_avg7': 11.51}, {'t': 1616731200, 'distT': 1616731200, 'percentVaccinatedDose2_avg7': 14.11}, {'t': 1617681600, 'distT': 1617681600, 'percentVaccinatedDose2_avg7': 16.99}, {'t': 1618545600, 'distT': 1618545600, 'percentVaccinatedDose2_avg7': 20.46}, {'t': 1619496000, 'distT': 1619496000, 'percentVaccinatedDose2_avg7': ...
# CPU times: user 1.78 s, sys: 63.1 ms, total: 1.84 s
# Wall time: 9.24 s

# %%
# %%time
# %run national_demog-mongodb.ipynb
# %run preprocessing_national_demog_wVaccine-mongodb.ipynb
# Out:
# kevin
# CPU times: user 160 ms, sys: 23.3 ms, total: 183 ms
# Wall time: 1.78 s

# %%
# %%time
# %run preprocessing_vaccineTrends-mongodb.ipynb
# Out:
# kevin
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# National Average
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with high proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with low proportion of African Americans
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with high proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with low proportion of population age 65+
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with high proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with low proportion with underlying condition
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with high proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# Counties with low proportion of Hispanic Americans
# ...
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Counties with low proportion of population with college education
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Inner City
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Large suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small suburbs
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Small cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Rural areas near cities
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# Remote rural areas
# CPU times: user 561 ms, sys: 117 ms, total: 677 ms
# Wall time: 2.16 s

# %%
# %%time
# %run preprocessing_vaccinationByRace-mongodb.ipynb
# Out:
# kevin
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Desktop/program/Shivani/emory-covid19/public/data/rawdata/preprocessing_vaccinationByRace-mongodb.ipynb in <module>
#     104 if __name__=="__main__":
#     105
# --> 106     vaccinationByRaceState()
#
# ~/Desktop/program/Shivani/emory-covid19/public/data/rawdata/preprocessing_vaccinationByRace-mongodb.ipynb in vaccinationByRaceState(fn)
#      69     date = ""
#      70     k = ""
# ---> 71     with open(fn, "r") as fp:
#      72         reader = csv.reader(fp)
#      73         header = next(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kffstaterace_static.csv'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <timed eval> in <module>
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2812                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2813                     if raise_exceptions:
# -> 2814                         result.raise_error()
#    2815                     elif not result.success:
#    2816                         break
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-11-6b3765261bec> in <module>
#     104 if __name__=="__main__":
#     105
# --> 106     vaccinationByRaceState()
#
# <ipython-input-11-6b3765261bec> in vaccinationByRaceState(fn)
#      69     date = ""
#      70     k = ""
# ---> 71     with open(fn, "r") as fp:
#      72         reader = csv.reader(fp)
#      73         header = next(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kffstaterace_static.csv'

# %%
# %%time
# %run preprocessing_staticracedata2-mongodb.ipynb
# Out:
# kevin
# CPU times: user 126 ms, sys: 24.3 ms, total: 150 ms
# Wall time: 3.03 s
