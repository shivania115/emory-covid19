# %%
import csv
import json
import pandas as pd
import numpy as np
from pprint import pprint
from collections import defaultdict,Counter
from dateutil.parser import *

# %%
def get_lineitem(d):
    Alpha = float(d["Alpha_B.1.1.7"])
    Beta = float(d["Beta_B.1.351"])
    B1621=float(d["B.1.621"])
    Delta_B=float(d["Delta_B.1.617.2"])
    Delta_AY1=float(d["Delta_AY.1"])
    Delta_AY2=float(d["Delta_AY.2"])
    Iota=float(d["Iota_B.1.526"])
    Eta=float(d['Eta_B.1.525'])
    OtherB16171=float(d["Other_B.1.617.1"])
    OtherB16173=float(d['Other_B.1.617.3'])
    Gamma = float(d["Gamma_P.1"])
    Other=float(d['Other_Other*'])
    try: 
        Alpha = float(d["Alpha_B.1.1.7"])
        Beta = float(d["Beta_B.1.351"])
        B1621=float(d["B.1.621"])
        Delta_B=float(d["Delta_B.1.617.2"])
        Delta_AY1=float(d["Delta_AY.1"])
        Delta_AY2=float(d["Delta_AY.2"])
        Iota=float(d["Iota_B.1.526"])
        Eta=float(d['Eta_B.1.525'])
        OtherB16171=float(d["Other_B.1.617.1"])
        OtherB16173=float(d['Other_B.1.617.3'])
        Gamma = float(d["Gamma_P.1"])
        Other=float(d['Other_Other*'])

    except ValueError:
        Alpha=0
        Beta=0
        B1621=0
        Delta_B=0
        Delta_AY1=0
        Delta_AY2=0
        Iota=0
        Eta=0
        Gamma=0
        OtherB16171=0
        OtherB16173=0
        Other=0
    return {"t":int(parse(d["weekEnding"]).timestamp()),
            "Alpha":Alpha,
            "Beta":Beta,
            "B1621":B1621,
            "Delta_B":Delta_B,
            "Iota":Iota,
            "Delta_AY1":Delta_AY1,
            "Delta_AY2":Delta_AY2,
            "Eta":Eta,
            "OtherB16171":OtherB16171,
            "OtherB16173":OtherB16173,
            "Gamma":Gamma,
            "Other":Other
    }
def variantSeries(fn="variantTimeseries.csv"):
        data=defaultdict(list)
        with open(fn,"r") as fp:
            reader=csv.reader(fp)
            header=next(reader)
            for row in reader:
                d={k:v.strip() for k,v in zip(header,row)}
                if d["weekEnding"]=="":
                    continue
                item=get_lineitem(d)
                k=""
                k=d["regionCode"].zfill(2)
                data[k].append(item)
            output=defaultdict(dict)
            for k,v in data.items():
                output[k]=v
            with open(f"../variantTimeseries.json","w") as fp:
                json.dump(output,fp,indent=2)
if __name__=="__main__":
    variantSeries()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-31ee08cfb982> in <module>
#      72                 json.dump(output,fp,indent=2)
#      73 if __name__=="__main__":
# ---> 74     variantSeries()
#
# <ipython-input-2-31ee08cfb982> in variantSeries(fn)
#      62                 if d["weekEnding"]=="":
#      63                     continue
# ---> 64                 item=get_lineitem(d)
#      65                 k=""
#      66                 k=d["regionCode"].zfill(2)
#
# <ipython-input-2-31ee08cfb982> in get_lineitem(d)
#       7     Delta_AY2=float(d["Delta_AY.2"])
#       8     Iota=float(d["Iota_B.1.526"])
# ----> 9     Eta=float(d['Eta_B.1.525'])
#      10     OtherB16171=float(d["Other_B.1.617.1"])
#      11     OtherB16173=float(d['Other_B.1.617.3'])
#
# KeyError: 'Eta_B.1.525'
