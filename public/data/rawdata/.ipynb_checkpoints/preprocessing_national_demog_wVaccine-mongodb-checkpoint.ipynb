# %%
import os
import pymongo
from dotenv import load_dotenv
import json
os.chdir("../../../../../MongoDB/EmoryCovid")
os.getcwd()
# Out:
# '/Users/starsdliu/Desktop/Rollins School of Public Health Research/Shivani - COVID-19/MongoDB/EmoryCovid'

# %%
load_dotenv()

USERNAME = os.getenv("USERNAME", "")
PASSWORD = os.getenv("PASSWORD", "")

client = pymongo.MongoClient(f"mongodb+srv://{USERNAME}:{PASSWORD}@healthequity.lkfar.mongodb.net/healthequity?retryWrites=true&w=majority")
CHED_static = client.healthequity.CHED_static
print(USERNAME)
client.healthequity.list_collection_names()
# Out:
# star
# ['var_option_mapping',
#  'GADPH_static',
#  'CHED_static',
#  'GADPH_series',
#  'CHED_series',
#  'gatech',
#  'test']

# %%
os.chdir("../../Dashboard/emory-covid19/public/data/rawdata")
os.getcwd()
client.healthequity.list_collection_names()
# Out:
# ['var_option_mapping',
#  'GADPH_static',
#  'CHED_static',
#  'GADPH_series',
#  'CHED_series',
#  'gatech',
#  'test']

# %%
import csv
import json
import pandas as pd
import numpy as np
from pprint import pprint
from collections import defaultdict, Counter
from dateutil.parser import *

def get_lineitem(d):
    
    
    popUS = None
    demogPop = None
    percentPop = None
    cases = None
    totalcases = None
    percentCases = None
    availableCases = None
    missingCases = None
    caserate = None
    deaths = None
    totaldeaths = None
    percentDeaths = None
    availableDeaths = None
    missingDeaths = None
    deathrate = None

    try:

        
        popUS = int(d["popUS"])
        demogPop = int(d["demogPop"])
        percentPop = float(d['percentPop'])
        cases = int(d['cases'])
        totalcases = int(d['totalcases'])
        percentCases = float(d["percentCases"])
        availableCases = int(d["availableCases"])
        missingCases = int(d["missingCases"])
        caserate = float(d["caserate"])
        deaths = int(d["deaths"])
        totaldeaths = int(d["totaldeaths"])
        percentDeaths = float(d["percentDeaths"])
        availableDeaths = int(d["availableDeaths"])
        missingDeaths = int(d["missingDeaths"])
        deathrate = float(d["deathrate"])

    except ValueError:
        
        popUS = 0
        demogPop = 0
        percentPop = 0
        cases = 0
        totalcases = 0
        percentCases = 0
        availableCases = 0
        missingCases = 0
        caserate = 0
        deaths = 0
        totaldeaths = 0
        percentDeaths = 0
        availableDeaths = 0
        missingDeaths = 0
        deathrate = 0

    return {
                "demogLabel": d['demogLabel'],
                "popUS" : popUS,
                "demogPop" : demogPop,
                "percentPop" : percentPop,
                "cases" : cases,
                "totalcases" : totalcases,
                "percentCases" : percentCases,
                "availableCases" : availableCases,
                "missingCases" : missingCases,
                "caserate" : caserate,
                "deaths" : deaths,
                "totaldeaths" : totaldeaths,
                "percentDeaths" : percentDeaths,
                "availableDeaths" : availableDeaths,
                "missingDeaths" : missingDeaths,
                "deathrate" : deathrate }

def get_VaccLineitem(d):
    
    
    popUS = None
    demogPop = None
    percentPop = None
    admDose1 = None
    pctAdmDose1 = None
    pctKnownAdmDose1 = None
    admDose2 = None
    pctAdmDose2 = None
    pctKnownAdmDose2 = None
    

    try:

        
        popUS = int(d["popUS"])
        demogPop = int(d["demogPop"])
        percentPop = float(d['percentPop'])
        admDose1 = float(d['admDose1'])
        pctAdmDose1 = float(d['pctAdmDose1'])
        pctKnownAdmDose1 = float(d["pctKnownAdmDose1"])
        admDose2 = float(d["admDose2"])
        pctAdmDose2 = float(d["pctAdmDose2"])
        pctKnownAdmDose2 = float(d["pctKnownAdmDose2"])
        

    except ValueError:
        
        popUS = 0
        demogPop = 0
        percentPop = 0
        admDose1 = 0
        pctAdmDose1 = 0
        pctKnownAdmDose1 = 0
        admDose2 = 0
        pctAdmDose2 = 0
        pctKnownAdmDose2 = 0
        

    return {
                "demogLabel": d['demogLabel'],
                "popUS" : popUS,
                "demogPop" : demogPop,
                "percentPop" : percentPop,
                "admDose1" : admDose1,
                "pctAdmDose1" : pctAdmDose1,
                "pctKnownAdmDose1" : pctKnownAdmDose1,
                "admDose2" : admDose2,
                "pctAdmDose2" : pctAdmDose2,
                "pctKnownAdmDose2" : pctKnownAdmDose2}

def demogdata(fn="USDemogData.csv"):
    
    data = defaultdict(list)
    subdata = defaultdict(list)
    j = ""
    date = ''
    with open(fn, "r") as fp:
        reader = csv.reader(fp)
        header = next(reader)
        for row in reader:
            d = {k:v.strip() for k, v in zip(header, row)}
            k = ""            
            if ('vaccine' in d['demographicVar']):
                item = get_VaccLineitem(d)
            else:
                item = get_lineitem(d)
                
            if (j == ""):
                j = d['demographicVar']
            if (j != d['demographicVar']):
                data[j].append(subdata);
                j = d['demographicVar']
                subdata = defaultdict(list)
                if d['demogLabel'] != "":
                    k = d['demogLabel']
                subdata[k].append(item)
            elif (j == d['demographicVar']):
                if d['demogLabel'] != "":
                    k = d['demogLabel']
                subdata[k].append(item)
            if date < d["date"]:
                date = d["date"]
                
        data[j].append(subdata);
                

            
    output = defaultdict(dict)
    for k, v in data.items():
        output[k]= v
        
    with open(f"../nationalDemogdata.json", "w") as fp:
            json.dump(output, fp, indent=2)
    with open(f"../nationalDemogdate.json", "w") as fp:
            json.dump({"date": date}, fp, indent=2)
    #update mongodb
#     CHED_static.insert_one({"all": "all", "tag": "nationalDemog", "nationalDemog": output})
#     CHED_static.update_one({"tag": "nationalDemog"}, {"$set":{"nationalDemog": output}})

            
if __name__=="__main__":

    demogdata()
    
#     demog_df = pd.read_csv("USDemogData.csv")
#     exclude_race = ["NHPI", "Unknown"]
#     max_race = demog_df[(demog_df['demographicVar'] == "race") & 
#                       (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['caserate'].idxmax()
#     max_race_group = demog_df[demog_df['demographicVar'] == "race"]['demogLabel'][max_race]
#     min_race = demog_df[(demog_df['demographicVar'] == "race") & 
#                       (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['caserate'].idxmin()
#     min_race_group = demog_df[demog_df['demographicVar'] == "race"]['demogLabel'][min_race]
#     max_race_value = max(demog_df[(demog_df['demographicVar'] == "race") & 
#                       (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['caserate'])
#     min_race_value = min(demog_df[(demog_df['demographicVar'] == "race") & 
#                       (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['caserate'])

#     race_descriptives = defaultdict(dict)
#     race_descriptives[max_race_group] = max_race_value
#     race_descriptives[min_race_group] = min_race_value
    
#     exclude_age = ["Unknown"]
#     age_sorted = np.sort(demog_df[(demog_df['demographicVar'] == "age") & 
#                           (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False])]['caserate'])

#     age_sorted
#     highest_age = demog_df[(demog_df['demographicVar'] == "age") & 
#                           (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
#                      (demog_df['caserate'] == age_sorted[-1])]['demogLabel'].values[0]

#     second_highest_age = demog_df[(demog_df['demographicVar'] == "age") & 
#                           (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
#                      (demog_df['caserate'] == age_sorted[-2])]['demogLabel'].values[0]

#     second_lowest_age = demog_df[(demog_df['demographicVar'] == "age") & 
#                           (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
#                      (demog_df['caserate'] == age_sorted[1])]['demogLabel'].values[0]

#     lowest_age = demog_df[(demog_df['demographicVar'] == "age") & 
#                           (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
#                      (demog_df['caserate'] == age_sorted[0])]['demogLabel'].values[0]


#     age_descriptives = defaultdict(dict)

#     age_descriptives[highest_age] = age_sorted[-1]
#     age_descriptives[second_highest_age] = age_sorted[-2]
#     age_descriptives[second_lowest_age] = age_sorted[1]
#     age_descriptives[lowest_age] = age_sorted[0]

#     demog_all = defaultdict(list)
#     demog_all['Race'].append(race_descriptives)
#     demog_all['Age'].append(age_descriptives)
    
# #     CHED_static.insert_one({"all": "all", "tag": "demogDescriptives", "demogDescriptives": demog_all})
#     CHED_static.update_one({"tag": "demogDescriptives"}, {"$set":{"demogDescriptives": demog_all}})
    

#     with open(f"../../../src/components/Pre-Processed Data/demogDescriptives.json", "w") as fp:
#         json.dump(demog_all, fp, indent=2)

# %%
import csv
import json
import pandas as pd
import numpy as np
from pprint import pprint
from collections import defaultdict, Counter
from dateutil.parser import *

demog_df = pd.read_csv("USDemogData.csv")
exclude_race = ["NHPI", "Unknown", "Multiple/Other"]
max_race = demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['deathrate'].idxmax()
max_race_group = demog_df[demog_df['demographicVar'] == "race"]['demogLabel'][max_race]
min_race = demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['deathrate'].idxmin()
min_race_group = demog_df[demog_df['demographicVar'] == "race"]['demogLabel'][min_race]
max_race_value = max(demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['deathrate'])
min_race_value = min(demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['deathrate'])

import csv
import json
import pandas as pd
import numpy as np
from pprint import pprint
from collections import defaultdict, Counter
from dateutil.parser import *

demog_df = pd.read_csv("USDemogData.csv")
exclude_race = ["NHPI", "Unknown"]
max_race = demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['percentCases'].idxmax()
max_race_group = demog_df[demog_df['demographicVar'] == "race"]['demogLabel'][max_race]
min_race = demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['percentCases'].idxmin()
min_race_group = demog_df[demog_df['demographicVar'] == "race"]['demogLabel'][min_race]
max_race_value = max(demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['percentCases'])
min_race_value = min(demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['percentCases'])

race_descriptives = defaultdict(dict)
race_descriptives[max_race_group] = max_race_value
race_descriptives[min_race_group] = min_race_value

max_raceD = demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['deathrate'].idxmax()
max_race_groupD = demog_df[demog_df['demographicVar'] == "race"]['demogLabel'][max_raceD]
min_raceD = demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['deathrate'].idxmin()
min_race_groupD = demog_df[demog_df['demographicVar'] == "race"]['demogLabel'][min_raceD]
max_race_valueD = max(demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['deathrate'])
min_race_valueD = min(demog_df[(demog_df['demographicVar'] == "race") & 
                  (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_race)) == False])]['deathrate'])

race_descriptivesD= defaultdict(dict)
race_descriptivesD[max_race_groupD] = max_race_valueD
race_descriptivesD[min_race_groupD] = min_race_valueD

exclude_age = ["Unknown"]
cases_age_sorted = np.sort(demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False])]['percentCases'])
deaths_age_sorted = np.sort(demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False])]['percentDeaths'])

#cases by age

highest_age = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
                 (demog_df['percentCases'] == cases_age_sorted[-1])]['demogLabel'].values[0]

second_highest_age = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
                 (demog_df['percentCases'] == cases_age_sorted[-2])]['demogLabel'].values[0]

second_lowest_age = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
                 (demog_df['percentCases'] == cases_age_sorted[1])]['demogLabel'].values[0]

lowest_age = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
                 (demog_df['percentCases'] == cases_age_sorted[0])]['demogLabel'].values[0]


#deaths by age

highest_death_age = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
                 (demog_df['percentDeaths'] == deaths_age_sorted[-1])]['demogLabel'].values[0]

second_highest_death_age = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
                 (demog_df['percentDeaths'] == deaths_age_sorted[-2])]['demogLabel'].values[0]

second_lowest_death_age = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
                 (demog_df['percentDeaths'] == deaths_age_sorted[1])]['demogLabel'].values[0]

lowest_death_age = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False]) &
                 (demog_df['percentDeaths'] == deaths_age_sorted[0])]['demogLabel'].values[0]


age_cases_descriptives = defaultdict(dict)
age_deaths_descriptives = defaultdict(dict)

age_cases_descriptives[highest_age] = cases_age_sorted[-1]
age_cases_descriptives[second_highest_age] = cases_age_sorted[-2]
age_cases_descriptives[second_lowest_age] = cases_age_sorted[1]
age_cases_descriptives[lowest_age] = cases_age_sorted[0]

age_deaths_descriptives[highest_death_age] = deaths_age_sorted[-1]
age_deaths_descriptives[second_highest_death_age] = deaths_age_sorted[-2]
age_deaths_descriptives[second_lowest_death_age] = deaths_age_sorted[1]
age_deaths_descriptives[lowest_death_age] = deaths_age_sorted[0]

demog_all = defaultdict(list)
demog_all['Race'].append({"cases": race_descriptives})
demog_all['Race'].append({"deaths": race_descriptivesD})
demog_all['Age'].append({"cases" : age_cases_descriptives})
demog_all['Age'].append({"deaths" : age_deaths_descriptives})



age_df = demog_df[(demog_df['demographicVar'] == "age") & 
                      (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False])]


#cases descriptives
str_list = []
case_age_desc_str = ""
gp_count = 0
index = 0

for row in range(len(age_df)):
    if (round(age_df["percentPop"][row], 0) < round(age_df["percentCases"][row],0) ):
        str_list.append(age_df["demogLabel"][row])
        gp_count += 1
        
case_age_desc_str = ", ".join(str_list)

if(gp_count > 1):
    str_end = " age groups"
elif(gp_count == 1):
    str_end = " age group"
    
    
if(gp_count == 1):
    case_age_desc_str = case_age_desc_str + " age group"
elif(gp_count > 2):
    for i in range(len(case_age_desc_str)):
        if(case_age_desc_str[i] == ','):
            gp_count -= 1
            if(gp_count == 1):
                index = i
                case_age_desc_str = case_age_desc_str[0:i+1]+ " and" + case_age_desc_str[i+1: len(case_age_desc_str)] + str_end
                break
elif(gp_count == 2):
    for i in range(len(case_age_desc_str)):
        if(gp_count == 2):
            if(case_age_desc_str[i] == ','):
                gp_count -= 1
                if(gp_count == 1):
                    index = i
                    case_age_desc_str = case_age_desc_str[0:i]+ " and" + case_age_desc_str[i+1: len(case_age_desc_str)] + str_end
                    break    

demog_all['AgeDescription'].append({"CasesDescription" : case_age_desc_str})

#deaths descriptives
str_list = []
death_age_desc_str = ""
gp_count = 0
index = 0

for row in range(len(age_df)):
    if (round(age_df["percentPop"][row], 0) < round(age_df["percentDeaths"][row],0) ):
        str_list.append(age_df["demogLabel"][row])
        gp_count += 1
        
death_age_desc_str = ", ".join(str_list)

if(gp_count > 1):
    str_end = " age groups"
elif(gp_count == 1):
    str_end = " age group"
    
    
if(gp_count == 1):
    death_age_desc_str = death_age_desc_str + " age group"
elif(gp_count > 2):
    for i in range(len(death_age_desc_str)):
        if(death_age_desc_str[i] == ','):
            gp_count -= 1
            if(gp_count == 1):
                index = i
                death_age_desc_str = death_age_desc_str[0:i+1]+ " and" + death_age_desc_str[i+1: len(death_age_desc_str)] + str_end
                break
elif(gp_count == 2):
    for i in range(len(death_age_desc_str)):
        if(gp_count == 2):
            if(death_age_desc_str[i] == ','):
                gp_count -= 1
                if(gp_count == 1):
                    index = i
                    death_age_desc_str = death_age_desc_str[0:i]+ " and" + death_age_desc_str[i+1: len(death_age_desc_str)] + str_end
                    break    
                    
demog_all['AgeDescription'].append({"DeathsDescription" : death_age_desc_str})

#     CHED_static.insert_one({"all": "all", "tag": "demogDescriptives", "demogDescriptives": demog_all})
# CHED_static.update_one({"tag": "demogDescriptives"}, {"$set":{"demogDescriptives": demog_all}})


with open(f"../../../src/components/Pre-Processed Data/demogDescriptives.json", "w") as fp:
    json.dump(demog_all, fp, indent=2)

# %%
# age_df = demog_df[(demog_df['demographicVar'] == "age") & 
#                       (demog_df['demogLabel'][demog_df['demogLabel'].str.contains('|'.join(exclude_age)) == False])]

# %%
# str_list = []
# age_desc_str = ""
# gp_count = 0
# index = 0

# for row in range(len(age_df)):
#     if (round(age_df["percentPop"][row], 0) < round(age_df["percentCases"][row],0) ):
#         str_list.append(age_df["demogLabel"][row])
#         gp_count += 1
        
# age_desc_str = ", ".join(str_list)
# age_desc_str
# gp_count
# Out:
# 4

# %%
# if(gp_count > 1):
#     str_end = " age groups"
# elif(gp_count == 1):
#     str_end = " age group"
    
    
# if(gp_count == 1):
#     age_desc_str = age_desc_str + " age group"
# elif(gp_count > 2):
#     for i in range(len(age_desc_str)):
#         if(age_desc_str[i] == ','):
#             gp_count -= 1
#             if(gp_count == 1):
#                 index = i
#                 age_desc_str = age_desc_str[0:i+1]+ " and" + age_desc_str[i+1: len(age_desc_str)] + str_end
#                 break
# elif(gp_count == 2):
#     for i in range(len(age_desc_str)):
#         if(gp_count == 2):
#             if(age_desc_str[i] == ','):
#                 gp_count -= 1
#                 if(gp_count == 1):
#                     index = i
#                     age_desc_str = age_desc_str[0:i]+ " and" + age_desc_str[i+1: len(age_desc_str)] + str_end
#                     break    
    
# age_desc_str
# Out:
# '18 - 29, 30 - 39, 40 - 49, and 50 - 64 age groups'

# %%
# Out:
# ','
